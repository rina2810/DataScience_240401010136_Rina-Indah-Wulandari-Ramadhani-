# %% [markdown]
# # Praktikum Data Science Pertemuan 1
#
# Nama : Rina Indah Wulandari Ramadhani
# NIM : 240401010136
# Kelas : IF404
#
# ## Topik
# Struktur Data Python, NumPy dan Pandas

# %%
import numpy as np
import pandas as pd

angka = np.array([10,20,30,40,50])

print("Array NumPy;")
print(angka)
print("Rata-rata", np.mean(angka))

df = pd.DataFrame({
    "Nama": ["Andi", "Budi", "Citra"],
    "Nilai" : [80,90,85]

})

print("\nDataFrame:")
print(pd.DataFrame)
# Out:
# Array NumPy;
# [10 20 30 40 50]
# Rata-rata 30.0
#
# DataFrame:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Kesimpulan
#
# Pada pertemuan ini saya mempelajari struktur data Python, penggunaan NumPy untuk komputasi numerik, dan Pandas untuk pengolahan data tabular.
