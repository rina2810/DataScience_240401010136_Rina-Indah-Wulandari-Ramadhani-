# %% [markdown]
# # Praktikum Data Science Pertemuan 1
#
# Nama : Rina Indah Wulandari Ramadhani
# NIM : 240401010136
# Kelas : IF404

# %%
print("Hello Data Science")

data = [10,20,30,40,50]

print("Jumlah Data :", len(data))
print("Nilai Maksium :", max(data))
print("Nilai Minium  :", min(data))
print("Rata-rata :", sum(data)/len(data))
# Out:
# Hello Data Science
# Jumlah Data : 5
# Nilai Maksium : 50
# Nilai Minium  : 10
# Rata-rata : 30.0

# %% [markdown]
# ## Kesimpulan
#
# Pada pertemuan ini saya mempelajari Pengenalan Data Science
